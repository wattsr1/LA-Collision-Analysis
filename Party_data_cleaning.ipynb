# %%
import pandas as pd

# %%
file_loc = "Resources/parties.csv"
parties_df = pd.read_csv(file_loc)
parties_df
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          CASE_ID  PARTY_NUMBER PARTY_TYPE AT_FAULT PARTY_SEX  PARTY_AGE  \
# 0       90655491             1          1        Y         M         26
# 1       90721682             1          1        Y         F         30
# 2       90721682             2          1        N         F         41
# 3       90600484             1          1        Y         M         70
# 4       90600484             2          3        N         -        998
# ...          ...           ...        ...      ...       ...        ...
# 410211  91151686             2          1        N         M         33
# 410212  91151686             3          1        N         M         31
# 410213  91151686             4          1        N         M         37
# ...

# %% [markdown]
# Inspect data for type and determine if any columns should be removed

# %%
parties_df.dtypes
# Out:
# CASE_ID                   int64
# PARTY_NUMBER              int64
# PARTY_TYPE               object
# AT_FAULT                 object
# PARTY_SEX                object
# PARTY_AGE                 int64
# PARTY_SOBRIETY           object
# PARTY_DRUG_PHYSICAL      object
# DIR_OF_TRAVEL            object
# PARTY_SAFETY_EQUIP_1     object
# PARTY_SAFETY_EQUIP_2     object
# FINAN_RESPONS            object
# SP_INFO_1                object
# SP_INFO_2                object
# SP_INFO_3                object
# OAF_VIOLATION_CODE       object
# OAF_VIOL_CAT             object
# OAF_VIOL_SECTION        float64
# OAF_VIOLATION_SUFFIX     object
# OAF_1                    object
# OAF_2                    object
# PARTY_NUMBER_KILLED       int64
# PARTY_NUMBER_INJURED      int64
# MOVE_PRE_ACC             object
# VEHICLE_YEAR            float64
# VEHICLE_MAKE             object
# STWD_VEHICLE_TYPE        object
# CHP_VEH_TYPE_TOWING     float64
# CHP_VEH_TYPE_TOWED      float64
# ...

# %% [markdown]
# Replace "-" with "" for each cell in the DataFrame

# %%
parties_df.replace("-", "NaN", regex=True)
# Out:
#          CASE_ID  PARTY_NUMBER PARTY_TYPE AT_FAULT PARTY_SEX  PARTY_AGE  \
# 0       90655491             1          1        Y         M         26
# 1       90721682             1          1        Y         F         30
# 2       90721682             2          1        N         F         41
# 3       90600484             1          1        Y         M         70
# 4       90600484             2          3        N       NaN        998
# ...          ...           ...        ...      ...       ...        ...
# 410211  91151686             2          1        N         M         33
# 410212  91151686             3          1        N         M         31
# 410213  91151686             4          1        N         M         37
# 410214  91156085             1          1        Y         M         48
# 410215  91156085             2          1        N         M         26
#
#        PARTY_SOBRIETY PARTY_DRUG_PHYSICAL DIR_OF_TRAVEL PARTY_SAFETY_EQUIP_1  \
# ...

# %%
# Determine number of null entries
parties_df.isnull().sum()
# Out:
# CASE_ID                      0
# PARTY_NUMBER                 0
# PARTY_TYPE                   0
# AT_FAULT                     0
# PARTY_SEX                    0
# PARTY_AGE                    0
# PARTY_SOBRIETY               0
# PARTY_DRUG_PHYSICAL       2219
# DIR_OF_TRAVEL                0
# PARTY_SAFETY_EQUIP_1         0
# PARTY_SAFETY_EQUIP_2         0
# FINAN_RESPONS            23123
# SP_INFO_1                    0
# SP_INFO_2                    0
# SP_INFO_3                    0
# OAF_VIOLATION_CODE       22692
# OAF_VIOL_CAT                 0
# OAF_VIOL_SECTION        387522
# OAF_VIOLATION_SUFFIX    402246
# OAF_1                        0
# OAF_2                        0
# PARTY_NUMBER_KILLED          0
# PARTY_NUMBER_INJURED         0
# MOVE_PRE_ACC                 0
# VEHICLE_YEAR             49015
# VEHICLE_MAKE                 3
# STWD_VEHICLE_TYPE            0
# CHP_VEH_TYPE_TOWING      27335
# CHP_VEH_TYPE_TOWED      406204
# RACE                     51759
# ...

# %%
# Drop columns with large number of null cells
parties_df = parties_df.drop(columns=["OAF_VIOL_SECTION", "OAF_VIOLATION_SUFFIX", "CHP_VEH_TYPE_TOWED", "INATTENTION"])
parties_df
# Out:
#          CASE_ID  PARTY_NUMBER PARTY_TYPE AT_FAULT PARTY_SEX  PARTY_AGE  \
# 0       90655491             1          1        Y         M         26
# 1       90721682             1          1        Y         F         30
# 2       90721682             2          1        N         F         41
# 3       90600484             1          1        Y         M         70
# 4       90600484             2          3        N         -        998
# ...          ...           ...        ...      ...       ...        ...
# 410211  91151686             2          1        N         M         33
# 410212  91151686             3          1        N         M         31
# 410213  91151686             4          1        N         M         37
# 410214  91156085             1          1        Y         M         48
# 410215  91156085             2          1        N         M         26
#
#        PARTY_SOBRIETY PARTY_DRUG_PHYSICAL DIR_OF_TRAVEL PARTY_SAFETY_EQUIP_1  \
# ...

# %%
# Drop null values
parties_df = parties_df.dropna()
parties_df
# Out:
#          CASE_ID  PARTY_NUMBER PARTY_TYPE AT_FAULT PARTY_SEX  PARTY_AGE  \
# 1       90721682             1          1        Y         F         30
# 2       90721682             2          1        N         F         41
# 5       90600867             1          1        N         M         29
# 6       90600867             2          1        Y         F         53
# 7       90603201             1          1        Y         F         67
# ...          ...           ...        ...      ...       ...        ...
# 410209  91149181             2          1        N         F         20
# 410210  91151686             1          1        Y         M         23
# 410211  91151686             2          1        N         M         33
# 410212  91151686             3          1        N         M         31
# 410213  91151686             4          1        N         M         37
#
#        PARTY_SOBRIETY PARTY_DRUG_PHYSICAL DIR_OF_TRAVEL PARTY_SAFETY_EQUIP_1  \
# ...

# %%
parties_df['ACCIDENT_YEAR'].value_counts()
# Out:
# 2017    96104
# 2018    95458
# 2019    91238
# Name: ACCIDENT_YEAR, dtype: int64
